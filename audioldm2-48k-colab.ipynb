# %% [markdown]
# <a href="https://colab.research.google.com/github/Dante890/Adv-Auto-Filter-Bot-V2/blob/main/audioldm2-48k-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/AudioLDM_48K_Text-to-HiFiAudio_Generation-hf /content/audioldm2
# !pip install -q git+https://github.com/huggingface/diffusers
# !pip install -q git+https://github.com/camenduru/AudioLDM2@v1.0
# !pip install -q transformers==4.30.2 huggingface_hub timm gradio==3.50.2

# %cd /content/audioldm2
# !python app.py
# Out:
# /content
# Cloning into '/content/audioldm2'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 53 (delta 27), reused 37 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 20.18 KiB | 5.04 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 108.2 MB/s eta 0:00:00
# ...
